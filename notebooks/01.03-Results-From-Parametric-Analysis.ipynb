# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# <!--NAVIGATION-->
# < [Making a Sensitivity Analysis](01.02-Sensitivity-Analysis.ipynb) | [Contents](Index.ipynb) | [Results From Sensitivity Analysis](01.04-Results-From-Sensitivity-Analysis.ipynb) >

# %% [markdown]
# # Results From Parametric Analysis

# %%
from surrogate_schema import APIClient

client = APIClient(
    api_key="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJzYW11ZWxkdWNoZXNuZUBtZS5jb20iLCJzY29wZXMiOiJtZSIsImV4cCI6MTY5MjQ1NTg0NX0.6_hb8_Xz_ftInynzmWBTNlFMwyG-im4lQSyycZ7zFHw",
)
client.whoami()
# Out:
# User(username='samuelduchesne@me.com', email='samuelduchesne@me.com', full_name='Samuel Letellier-Duchesne', disabled=False, valid_until=datetime.datetime(2023, 8, 19, 14, 37, 25))

# %%
from surrogate_schema import BuildingAnalysis

# %%
analysis = BuildingAnalysis.parse_file("analysis.json")

# %%
df = analysis.get_parametric_results()
df
# Out:
#     WINU  WWR  EUI_kBtu_per_sqft  TEDI_kBtu_per_sqft  CEDI_kBtu_per_sqft  \
# 0   0.14  0.1         507.116449           51.454628          251.859594
# 1   0.14  0.9         503.893287           57.651239          256.338263
# 2   0.80  0.1         507.116449           51.454628          251.859594
# 3   0.80  0.9         503.893287           57.651239          256.338263
# 4   0.14  0.5         500.516210           54.386635          251.606950
# 5   0.30  0.5         500.516210           54.386635          251.606950
# 6   0.40  0.5         500.516210           54.386635          251.606950
# 7   0.50  0.5         500.516210           54.386635          251.606950
# 8   0.80  0.5         500.516210           54.386635          251.606950
# 9   0.40  0.1         507.116449           51.454628          251.859594
# 10  0.40  0.3         502.072279           52.925274          250.851297
# 11  0.40  0.7         501.403506           55.980618          253.585861
# 12  0.40  0.9         503.893287           57.651239          256.338263
# 13  0.80  0.3         502.072279           52.925274          250.851297
# 14  0.50  0.3         502.072279           52.925274          250.851297
# 15  0.80  0.7         501.403506           55.980618          253.585861
# 16  0.50  0.1         507.116449           51.454628          251.859594
# 17  0.50  0.7         501.403506           55.980618          253.585861
# 18  0.30  0.3         502.072279           52.925274          250.851297
# 19  0.30  0.1         507.116449           51.454628          251.859594
# 20  0.30  0.9         503.893287           57.651239          256.338263
# 21  0.14  0.3         502.072279           52.925274          250.851297
# 22  0.14  0.7         501.403506           55.980618          253.585861
# 23  0.50  0.9         503.893287           57.651239          256.338263
# 24  0.30  0.7         501.403506           55.980618          253.585861
#
#     EDI_kBtu_per_sqft  peak_cooling_W_per_sqft  peak_heating_W_per_sqft  \
# 0          303.314222                 7.683743                 0.125843
# 1          313.989502                 9.920742                 0.776184
# 2          303.314222                 7.683743                 0.125843
# 3          313.989502                 9.920742                 0.776184
# 4          305.993585                 8.827118                 0.500928
# 5          305.993585                 8.827118                 0.500928
# 6          305.993585                 8.827118                 0.500928
# 7          305.993585                 8.827118                 0.500928
# 8          305.993585                 8.827118                 0.500928
# 9          303.314222                 7.683743                 0.125843
# 10         303.776571                 8.253850                 0.315003
# 11         309.566479                 9.383575                 0.644472
# 12         313.989502                 9.920742                 0.776184
# 13         303.776571                 8.253850                 0.315003
# 14         303.776571                 8.253850                 0.315003
# 15         309.566479                 9.383575                 0.644472
# 16         303.314222                 7.683743                 0.125843
# 17         309.566479                 9.383575                 0.644472
# 18         303.776571                 8.253850                 0.315003
# 19         303.314222                 7.683743                 0.125843
# 20         313.989502                 9.920742                 0.776184
# 21         303.776571                 8.253850                 0.315003
# 22         309.566479                 9.383575                 0.644472
# 23         313.989502                 9.920742                 0.776184
# 24         309.566479                 9.383575                 0.644472
#
#     dataset
# 0   modeled
# 1   modeled
# 2   modeled
# 3   modeled
# 4   modeled
# 5   modeled
# 6   modeled
# 7   modeled
# 8   modeled
# 9   modeled
# 10  modeled
# 11  modeled
# 12  modeled
# 13  modeled
# 14  modeled
# 15  modeled
# 16  modeled
# 17  modeled
# 18  modeled
# 19  modeled
# 20  modeled
# 21  modeled
# 22  modeled
# 23  modeled
# 24  modeled

# %%
from surrogate_schema.utilities import InterpolationMethod

analysis.get_parametric_results(interpolate_method=InterpolationMethod.linear)
# Out:
#     WINU  WWR  dataset  EUI_kBtu_per_sqft  TEDI_kBtu_per_sqft  \
# 0   0.14  0.1  modeled         507.116449           51.454628
# 1   0.14  0.3  modeled         502.072279           52.925274
# 2   0.14  0.5  modeled         500.516210           54.386635
# 3   0.14  0.7  modeled         501.403506           55.980618
# 4   0.14  0.9  modeled         503.893287           57.651239
# 5   0.30  0.1  modeled         507.116449           51.454628
# 6   0.30  0.3  modeled         502.072279           52.925274
# 7   0.30  0.5  modeled         500.516210           54.386635
# 8   0.30  0.7  modeled         501.403506           55.980618
# 9   0.30  0.9  modeled         503.893287           57.651239
# 10  0.40  0.1  modeled         507.116449           51.454628
# 11  0.40  0.3  modeled         502.072279           52.925274
# 12  0.40  0.5  modeled         500.516210           54.386635
# 13  0.40  0.7  modeled         501.403506           55.980618
# 14  0.40  0.9  modeled         503.893287           57.651239
# 15  0.50  0.1  modeled         507.116449           51.454628
# 16  0.50  0.3  modeled         502.072279           52.925274
# 17  0.50  0.5  modeled         500.516210           54.386635
# 18  0.50  0.7  modeled         501.403506           55.980618
# 19  0.50  0.9  modeled         503.893287           57.651239
# 20  0.80  0.1  modeled         507.116449           51.454628
# 21  0.80  0.3  modeled         502.072279           52.925274
# 22  0.80  0.5  modeled         500.516210           54.386635
# 23  0.80  0.7  modeled         501.403506           55.980618
# 24  0.80  0.9  modeled         503.893287           57.651239
#
#     CEDI_kBtu_per_sqft  EDI_kBtu_per_sqft  peak_cooling_W_per_sqft  \
# 0           251.859594         303.314222                 7.683743
# 1           250.851297         303.776571                 8.253850
# 2           251.606950         305.993585                 8.827118
# 3           253.585861         309.566479                 9.383575
# 4           256.338263         313.989502                 9.920742
# 5           251.859594         303.314222                 7.683743
# 6           250.851297         303.776571                 8.253850
# 7           251.606950         305.993585                 8.827118
# 8           253.585861         309.566479                 9.383575
# 9           256.338263         313.989502                 9.920742
# 10          251.859594         303.314222                 7.683743
# 11          250.851297         303.776571                 8.253850
# 12          251.606950         305.993585                 8.827118
# 13          253.585861         309.566479                 9.383575
# 14          256.338263         313.989502                 9.920742
# 15          251.859594         303.314222                 7.683743
# 16          250.851297         303.776571                 8.253850
# 17          251.606950         305.993585                 8.827118
# 18          253.585861         309.566479                 9.383575
# 19          256.338263         313.989502                 9.920742
# 20          251.859594         303.314222                 7.683743
# 21          250.851297         303.776571                 8.253850
# 22          251.606950         305.993585                 8.827118
# 23          253.585861         309.566479                 9.383575
# 24          256.338263         313.989502                 9.920742
#
#     peak_heating_W_per_sqft
# 0                  0.125843
# 1                  0.315003
# 2                  0.500928
# 3                  0.644472
# 4                  0.776184
# 5                  0.125843
# 6                  0.315003
# 7                  0.500928
# 8                  0.644472
# 9                  0.776184
# 10                 0.125843
# 11                 0.315003
# 12                 0.500928
# 13                 0.644472
# 14                 0.776184
# 15                 0.125843
# 16                 0.315003
# 17                 0.500928
# 18                 0.644472
# 19                 0.776184
# 20                 0.125843
# 21                 0.315003
# 22                 0.500928
# 23                 0.644472
# 24                 0.776184

# %% [markdown]
# <!--NAVIGATION-->
# < [Making a Sensitivity Analysis](01.02-Sensitivity-Analysis.ipynb) | [Contents](Index.ipynb) | [Results From Sensitivity Analysis](01.04-Results-From-Sensitivity-Analysis.ipynb) >
