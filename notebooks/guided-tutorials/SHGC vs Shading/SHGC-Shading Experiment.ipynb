# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# This Jupyter notebook demonstrates the use of the `surrogate_schema`library to perform a specific parametric building energy analysis on AWS Batch. It starts by defining a parameter space and generating manually a set of samples within that space.
#
# A pre-existing BuildingAnalysis object is loaded, which specifies the analysis that has already been performed. If you wish, you can uncomment the lines and the necessary files are uploaded to S3. The job is then submitted to AWS Batch, and the status of the job is tracked.
#
# Finally, the results of the job are retrieved and saved to a JSON file.

# %%
from surrogate_schema import __version__
__version__
# Out:
# '0.10.1'

# %%
from surrogate_schema import Space, SampledSpace, BuildingAnalysis
from surrogate_schema import APIClient

# typical block to authenticate to the API
client = APIClient(
    api_url="https://api.elementa.nyc",
    api_key="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJzYW11ZWxkdWNoZXNuZUBtZS5jb20iLCJzY29wZXMiOiJtZSIsImV4cCI6MTY5MjQ1NTg0NX0.6_hb8_Xz_ftInynzmWBTNlFMwyG-im4lQSyycZ7zFHw",
)
client.whoami()  # shows that you are properly authenticated
# Out:
# User(username='samuelduchesne@me.com', email='samuelduchesne@me.com', full_name='Samuel Letellier-Duchesne', disabled=False, valid_until=datetime.datetime(2023, 8, 19, 14, 37, 25))

# %% [markdown]
# The next cell creates a Space object which defines the dimensions of the parameter space to be explored.

# %%
from surrogate_schema.space.design_space import SupportedParameter

space = Space(
    dimensions=[
        dict(name=SupportedParameter.WINSHGC, low=0.0, high=.99),
        dict(name=SupportedParameter.SHADING_OVERHANG_PROJECTION, low=0, high=1),
        dict(name=SupportedParameter.WINU, categories=[.45,])
    ]
)
space
# Out:
# Space(dimensions=[Dimension(name=<SupportedParameter.WINSHGC: 'WINSHGC'>, categories=None, low=0.0, high=0.99, base=10, transformer=<ContinuousTransform.identity: 'identity'>, prior=<Prior.uniform: 'uniform'>, dtype=dtype('float64'), practical_ranges=None), Dimension(name=<SupportedParameter.SHADING_OVERHANG_PROJECTION: 'SHADING_OVERHANG_PROJECTION'>, categories=None, low=0.0, high=1.0, base=10, transformer=<ContinuousTransform.identity: 'identity'>, prior=<Prior.uniform: 'uniform'>, dtype=dtype('float64'), practical_ranges=None), Dimension(name=<SupportedParameter.WINU: 'WINU'>, categories=[0.45], low=None, high=None, base=10, transformer=<CategoricalTransform.label: 'label'>, prior=None, dtype=dtype('float64'), practical_ranges={'Passive House': 0.14, 'Single Pane': 1.02, 'Double, clear': 0.5, 'Double, low-e': 0.352})], space_id=UUID('e2638eed-9002-47ae-a47d-9af06c204b84'), baseline={}, version='0.0.0')

# %% [markdown]
# A SampledSpace object is created, which generates a list of samples in the defined Space. The samples are then converted to a Pandas DataFrame to be viewed.

# %% [markdown]
# The next cell loads an existing BuildingAnalysis object from a JSON file. If you want to create a new BuildingAnalysis object, you can uncomment the necessary code in this cell and run it.

# %%
from surrogate_schema.analysis import SupportedHVACTemplate

# analysis = BuildingAnalysis.parse_file("./analysis.json")

analysis = BuildingAnalysis(
    company="Carbon Signal",
    project="Experiement",
    local_epw="./USA_MA_Boston-Logan.Intl.AP.725090_TMY3.epw",
    local_ddyname="./USA_MA_Boston-Logan.Intl.AP.725090_TMY3.ddy",
    local_template="./BostonTemplateLibrary.json",
    hvac_template_name=SupportedHVACTemplate.SimpleIdealLoadsSystem,
    design_space=space,
    baseline={"WINSHGC": .99, "SHADING_OVERHANG_PROJECTION": 0, "WINU": 0.45}
)

# %%
ss = analysis.create_space(50, sensitivity_samples=50)
ss.to_df()
# Out:
#     WINSHGC  SHADING_OVERHANG_PROJECTION  WINU
# 0     0.000                     0.000000  0.45
# 1     0.000                     1.000000  0.45
# 2     0.045                     0.590909  0.45
# 3     0.066                     0.000000  0.45
# 4     0.132                     0.000000  0.45
# 5     0.135                     0.500000  0.45
# 6     0.198                     0.000000  0.45
# 7     0.225                     0.954545  0.45
# 8     0.264                     0.000000  0.45
# 9     0.315                     0.045455  0.45
# 10    0.330                     0.000000  0.45
# 11    0.396                     0.000000  0.45
# 12    0.405                     0.227273  0.45
# 13    0.462                     0.000000  0.45
# 14    0.495                     0.863636  0.45
# 15    0.528                     0.000000  0.45
# 16    0.585                     0.409091  0.45
# 17    0.594                     0.000000  0.45
# 18    0.660                     0.000000  0.45
# 19    0.675                     0.772727  0.45
# 20    0.726                     0.000000  0.45
# 21    0.765                     0.318182  0.45
# 22    0.792                     0.000000  0.45
# 23    0.855                     0.681818  0.45
# 24    0.858                     0.000000  0.45
# 25    0.924                     0.000000  0.45
# 26    0.945                     0.136364  0.45
# 27    0.990                     0.000000  0.45
# 28    0.990                     0.066667  0.45
# 29    0.990                     0.133333  0.45
# 30    0.990                     0.200000  0.45
# 31    0.990                     0.266667  0.45
# 32    0.990                     0.333333  0.45
# 33    0.990                     0.400000  0.45
# 34    0.990                     0.466667  0.45
# 35    0.990                     0.533333  0.45
# 36    0.990                     0.600000  0.45
# 37    0.990                     0.666667  0.45
# 38    0.990                     0.733333  0.45
# 39    0.990                     0.800000  0.45
# 40    0.990                     0.866667  0.45
# 41    0.990                     0.933333  0.45
# 42    0.990                     1.000000  0.45

# %% [markdown]
# The following cell prepares a job to run on AWS Batch by uploading necessary files to S3. The `prepare_job` method takes arguments such as the job definition and whether or not to upload simulation files to S3 (if you wish to retreive them later, otherwise they are deleted).

# %%
analysis.prepare_job(upload_to_s3=True, job_definition="energyplus-22-1-0")
# Out:
# INFO - uploaded 'BostonTemplateLibrary.json' to s3://surrogate-api/parametric/051be7a3-e61c-41ec-bd0b-58550f90bf6f/BostonTemplateLibrary.json
# INFO - Uploaded parameter file to 's3://surrogate-api/parametric/051be7a3-e61c-41ec-bd0b-58550f90bf6f/parameters.json'
# GenerateAndRunJob(jobName='parametric_051be7a3-e61c-41ec-bd0b-58550f90bf6f', jobQueue='dev', arrayProperties=ArrayProperty(size=43), tags={'Project': 'Experiement', 'Company': 'Carbon Signal'}, propagateTags=True, parameters=Parameters(log_level=<LogLevel.INFO: 'INFO'>, run_number=None, parameters=UrlValue('s3://surrogate-api/parametric/051be7a3-e61c-41ec-bd0b-58550f90bf6f/parameters.json', scheme='s3', host='surrogate-api', host_type='int_domain', path='/parametric/051be7a3-e61c-41ec-bd0b-58550f90bf6f/parameters.json'), prototype_model=None, form_factor=None, template_library=UrlValue('s3://surrogate-api/parametric/051be7a3-e61c-41ec-bd0b-58550f90bf6f/BostonTemplateLibrary.json', scheme='s3', host='surrogate-api', host_type='int_domain', path='/parametric/051be7a3-e61c-41ec-bd0b-58550f90bf6f/BostonTemplateLibrary.json'), ddy_file=None, idf_output_dir=UrlValue('s3://surrogate-api/parametric/051be7a3-e61c-41ec-bd0b-58550f90bf6f/idfs/', scheme='s3', host='surrogate-api', host_type='int_domain', path='/parametric/051be7a3-e61c-41ec-bd0b-58550f90bf6f/idfs/'), output_meters=None, output_variables=None, include=None, table_name='single-building-analysis', start_index='0', reporting_frequency='Monthly', upload_to_s3=True), containerOverrides=ContainerOverrides(command=['--log-level', 'Ref::log_level', 'generate-idf-and-run', '--parameters', 'Ref::parameters', '--template-library', 'Ref::template_library', '--idf-output-dir', 'Ref::idf_output_dir', '--table-name', 'Ref::table_name', '--start-index', 'Ref::start_index', '--reporting-frequency', 'Ref::reporting_frequency', '--upload-to-s3'], resourceRequirements=[ResourceRequirement(type='MEMORY', value='2048'), ResourceRequirement(type='VCPU', value='1')]), jobDefinition=<JobDefinitions.energyplus_22_1_0: 'energyplus-22-1-0'>)

# %% [markdown]
# In the next cell, the job is submitted to AWS Batch with the submit_job method.

# %%
analysis.submit_job()
# Out:
# SubmitJobResponse(jobArn='arn:aws:batch:us-east-2:664685589714:job/b5d03285-1de9-4865-a7b5-a6edf788ceda', jobName='parametric_051be7a3-e61c-41ec-bd0b-58550f90bf6f', jobId=UUID('b5d03285-1de9-4865-a7b5-a6edf788ceda'))

# %% [markdown]
# After submitting the job, the save method is used to save the BuildingAnalysis object to a JSON file.

# %%
analysis.save("analysis.json")

# %% [markdown]
# The next cell uses the `track_status` method to check the status of the running job.

# %%
analysis.track_status()
# Out:
# 0it [00:00, ?it/s]

# %%
# log = analysis.get_job_logs(42, startFromHead=False)

# %%
sensitivity = analysis.get_sensitivity_results()

# %%
sensitivity.to_df()
# Out:
#                         Variable  WINSHGC  SHADING_OVERHANG_PROJECTION  WINU  \
# RUN
# 0                        WINSHGC    0.000                     0.000000  0.45
# 3                        WINSHGC    0.066                     0.000000  0.45
# 4                        WINSHGC    0.132                     0.000000  0.45
# 6                        WINSHGC    0.198                     0.000000  0.45
# 8                        WINSHGC    0.264                     0.000000  0.45
# 10                       WINSHGC    0.330                     0.000000  0.45
# 11                       WINSHGC    0.396                     0.000000  0.45
# 13                       WINSHGC    0.462                     0.000000  0.45
# 15                       WINSHGC    0.528                     0.000000  0.45
# 17                       WINSHGC    0.594                     0.000000  0.45
# 18                       WINSHGC    0.660                     0.000000  0.45
# 20                       WINSHGC    0.726                     0.000000  0.45
# 22                       WINSHGC    0.792                     0.000000  0.45
# 24                       WINSHGC    0.858                     0.000000  0.45
# 25                       WINSHGC    0.924                     0.000000  0.45
# 27                       WINSHGC    0.990                     0.000000  0.45
# 27   SHADING_OVERHANG_PROJECTION    0.990                     0.000000  0.45
# 28   SHADING_OVERHANG_PROJECTION    0.990                     0.066667  0.45
# 29   SHADING_OVERHANG_PROJECTION    0.990                     0.133333  0.45
# 30   SHADING_OVERHANG_PROJECTION    0.990                     0.200000  0.45
# 31   SHADING_OVERHANG_PROJECTION    0.990                     0.266667  0.45
# 32   SHADING_OVERHANG_PROJECTION    0.990                     0.333333  0.45
# 33   SHADING_OVERHANG_PROJECTION    0.990                     0.400000  0.45
# 34   SHADING_OVERHANG_PROJECTION    0.990                     0.466667  0.45
# 35   SHADING_OVERHANG_PROJECTION    0.990                     0.533333  0.45
# 36   SHADING_OVERHANG_PROJECTION    0.990                     0.600000  0.45
# 37   SHADING_OVERHANG_PROJECTION    0.990                     0.666667  0.45
# 38   SHADING_OVERHANG_PROJECTION    0.990                     0.733333  0.45
# 39   SHADING_OVERHANG_PROJECTION    0.990                     0.800000  0.45
# 40   SHADING_OVERHANG_PROJECTION    0.990                     0.866667  0.45
# 41   SHADING_OVERHANG_PROJECTION    0.990                     0.933333  0.45
# 42   SHADING_OVERHANG_PROJECTION    0.990                     1.000000  0.45
# 27                          WINU    0.990                     0.000000  0.45
#
#     Recommended Baseline  EUI_kBtu_per_sqft  TEDI_kBtu_per_sqft  \
# RUN
# 0            no       no          77.078455           17.087779
# 3            no       no          61.567731           22.177785
# 4            no       no          61.049308           20.431651
# 6            no       no          61.451002           19.134375
# 8            no       no          62.125604           18.032004
# 10           no       no          63.178785           17.103495
# 11           no       no          64.513675           16.343632
# 13           no       no          66.096969           15.749332
# 15           no       no          67.718108           15.223862
# 17           no       no          69.628704           14.879320
# 18           no       no          71.642268           14.643903
# 20           no       no          73.757005           14.519418
# 22           no       no          75.879255           14.471911
# 24           no       no          78.077019           14.496338
# 25           no       no          80.457993           14.625601
# 27           no      yes          81.976404           14.583639
# 27           no      yes          81.976404           14.583639
# 28           no       no          80.261862           14.508704
# 29           no       no          78.586958           14.467220
# 30           no       no          77.105168           14.451880
# 31           no       no          75.744292           14.465040
# 32           no       no          74.421902           14.479722
# 33           no       no          73.146449           14.464235
# 34           no       no          71.939817           14.442198
# 35           no       no          70.970430           14.490145
# 36           no       no          69.976089           14.527698
# 37           no       no          69.084173           14.568372
# 38           no       no          68.251204           14.617378
# 39           no       no          67.511362           14.660904
# 40           no       no          66.787626           14.704211
# 41           no       no          66.101238           14.761974
# 42           no       no          65.477463           14.826786
# 27           no      yes          81.976404           14.583639
#
#      CEDI_kBtu_per_sqft  EDI_kBtu_per_sqft  sensible_peak_cooling_W_per_sqft  \
# RUN
# 0             29.828788          46.916567                          5.607416
# 3             15.025366          37.203151                          2.776683
# 4             15.846606          36.278257                          2.988633
# 6             17.050540          36.184915                          3.285465
# 8             18.314744          36.346748                          3.566736
# 10            19.728143          36.831638                          3.827524
# 11            21.227542          37.571174                          4.084738
# 13            22.790167          38.539499                          4.356538
# 15            24.317817          39.541679                          4.631956
# 17            25.959090          40.838410                          4.904498
# 18            27.594831          42.238734                          5.166984
# 20            29.234584          43.754002                          5.434589
# 22            30.818328          45.290239                          5.704179
# 24            32.416820          46.913158                          5.970808
# 25            34.103277          48.728878                          6.234570
# 27            35.244485          49.828124                          6.442328
# 27            35.244485          49.828124                          6.442328
# 28            34.068584          48.577288                          6.191366
# 29            32.889739          47.356959                          5.946037
# 30            31.856463          46.308343                          5.708318
# 31            30.926686          45.391726                          5.488539
# 32            29.992396          44.472118                          5.294149
# 33            29.095562          43.559797                          5.119684
# 34            28.242847          42.685045                          4.960561
# 35            27.537299          42.027444                          4.804626
# 36            26.783533          41.311231                          4.673597
# 37            26.100684          40.669056                          4.556930
# 38            25.446079          40.063457                          4.451972
# 39            24.874639          39.535543                          4.354206
# 40            24.307771          39.011982                          4.307468
# 41            23.749590          38.511564                          4.287314
# 42            23.230965          38.057751                          4.271102
# 27            35.244485          49.828124                          6.442328
#
#      sensible_peak_heating_W_per_sqft time_of_peak_cooling  \
# RUN
# 0                            2.896522         11-JUL-16:00
# 3                            4.033860         01-AUG-12:05
# 4                            3.811672         11-JUL-16:00
# 6                            3.578389         11-JUL-16:00
# 8                            3.631162         11-JUL-16:00
# 10                           3.357415         11-JUL-16:00
# 11                           3.245655         11-JUL-16:00
# 13                           2.631495         11-JUL-16:00
# 15                           2.666613         11-JUL-16:00
# 17                           2.569224         11-JUL-16:00
# 18                           2.547250         11-JUL-16:00
# 20                           2.536799         11-JUL-16:00
# 22                           2.469600         11-JUL-16:00
# 24                           2.417465         11-JUL-16:00
# 25                           2.383912         11-JUL-16:00
# 27                           2.245627         11-JUL-16:00
# 27                           2.245627         11-JUL-16:00
# 28                           2.336420         11-JUL-16:00
# 29                           2.377537         11-JUL-16:00
# 30                           2.369266         11-JUL-16:00
# 31                           2.412744         11-JUL-16:00
# 32                           2.457541         11-JUL-16:00
# 33                           2.426560         11-JUL-16:00
# 34                           2.490050         11-JUL-16:00
# 35                           2.455987         11-JUL-16:00
# 36                           2.450599         11-JUL-16:00
# 37                           2.490115         11-JUL-16:00
# 38                           2.465522         11-JUL-16:00
# 39                           2.488971         11-JUL-16:00
# 40                           2.532502         11-JUL-13:40
# 41                           2.525659         11-JUL-13:40
# 42                           2.587717         11-JUL-13:40
# 27                           2.245627         11-JUL-16:00
#
#     time_of_peak_heating  peak_heating_W_per_sqft  peak_cooling_W_per_sqft
# RUN
# 0           23-JAN-05:40                 4.520780                 8.248869
# 3           23-JAN-05:37                 4.761738                 5.170281
# 4           23-JAN-02:50                 4.675877                 5.150287
# 6           23-JAN-02:51                 4.902843                 5.303288
# 8           23-JAN-03:33                 4.801022                 5.409111
# 10          23-JAN-05:40                 4.747838                 5.668263
# 11          23-JAN-05:34                 4.466914                 6.236958
# 13          23-JAN-01:00                 4.395918                 6.650844
# 15          23-JAN-04:00                 4.385170                 7.276620
# 17          23-JAN-05:10                 4.283386                 6.979436
# 18          23-JAN-02:30                 4.177511                 7.182946
# 20          23-JAN-05:50                 4.281027                 8.114119
# 22          23-JAN-06:10                 4.214882                 7.596542
# 24          23-JAN-04:00                 4.151648                 7.895318
# 25          23-JAN-05:40                 3.978686                 8.177508
# 27          23-JAN-06:00                 3.838271                 8.438653
# 27          23-JAN-06:00                 3.838271                 8.438653
# 28          23-JAN-06:15                 3.861021                 8.112062
# 29          23-JAN-05:35                 3.959305                 8.765487
# 30          23-JAN-05:00                 4.091530                 8.700090
# 31          23-JAN-06:10                 4.155198                 8.493522
# 32          23-JAN-06:00                 4.195692                 7.065435
# 33          23-JAN-06:50                 4.137097                 8.164700
# 34          23-JAN-06:00                 4.249380                 6.745057
# 35          23-JAN-04:00                 4.253239                 6.595913
# 36          23-JAN-05:20                 4.132656                 6.456617
# 37          23-JAN-04:30                 4.298900                 7.014234
# 38          23-JAN-02:70                 4.292831                 7.135958
# 39          23-JAN-05:15                 4.199570                 6.972324
# 40          23-JAN-07:00                 4.361965                 6.983722
# 41          23-JAN-05:35                 4.263629                 6.803308
# 42          23-JAN-04:00                 4.320378                 6.370241
# 27          23-JAN-06:00                 3.838271                 8.438653

# %%
fig, ax = sensitivity.plot_sensitivity("EUI_kBtu_per_sqft", exclude={'WINU'})
# Out:
# /opt/tljh/user/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /opt/tljh/user/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# Finally, the `get_results` method is used to retrieve the results of the job.

# %%
log = analysis.get_job_logs(0)
# Out:
# INFO - 2023-04-21 18:40:37,855 - aws_batch.cli.generate_idf_and_run - INFO - processing 0.
# INFO - 2023-04-21 18:40:37,855 - awsio.aws_io - INFO - Download file s3://surrogate-api/parametric/6df56aa8-131f-494d-a9f5-67b9aa5474a1/parameters.json from s3.
# INFO - 2023-04-21 18:40:38,184 - aws_batch.energyplus.energyPlusProcess - INFO - Using run number=0
# INFO - 2023-04-21 18:40:38,184 - aws_batch.energyplus.energyPlusProcess - INFO - Generating IDF with parameters:
# INFO - KEY='6df56aa8-131f-494d-a9f5-67b9aa5474a1' IDD=None DDY='s3://surrogate-api/parametric/6df56aa8-131f-494d-a9f5-67b9aa5474a1/USA_MA_Boston-Logan.Intl.AP.725090_TMY3.ddy' RUN=0 ENSEMBLE=None FORMFACT=None ECM=None WWR=None WWRN=None WWRE=None WWRS=None WWRW=None WINU=None WINUN=None WINUE=None WINUS=None WINUW=None WINSHGC=0.0 WINSHGCN=None WINSHGCS=None WINSHGCE=None WINSHGCW=None WALLR=None ROOFR=None EPDSCH=None LPDSCH=None EPD=None LPD=None HRV=None ACH=None VENTSCH=None HUMIDMAX=None SATRESET=None FANPOWER=None OASYSTEM=None ECON=None DELTA_FANPOWER=None EPW='s3://surrogate-api/parametric/6df56aa8-131f-494d-a9f5-67b9aa5474a1/USA_MA_Boston-Logan.Intl.AP.725090_TMY3.epw' INFIL=None COOLCOP=None HEATCOP=None ELECTRIFICATION=None THERMALMASS=None ROTATE=None NATVENT_ACH=None SHADING_OVERHANG_PROJECTION=0.0 SCALE_X=None HVACTEMPLATE='SimpleIdealLoadsSystem' HVACTEMPLATE_ZONESCHEME=<SystemScheme.SINGLE_SYSTEM: 1> FANPOWERMINIMUMFLOWFRACTION=None FLOORS=None OCCSCH=None HTGSPSCH=None CLGSPSCH=None USESCH=None PERIM_DEPTH=3 FOOTPRINT_AREA=400 FLOOR_TO_FLOOR_HEIGHT=3
# INFO - 2023-04-21 18:40:41,303 - aws_batch.shoeboxer.shoebox - INFO - Added default schedules.
# INFO - 2023-04-21 18:40:47,747 - archetypal - INFO - No 'ZONEVENTILATION:DESIGNFLOWRATE' created since IsScheduledVentilationOn == False.
# INFO - 2023-04-21 18:40:47,747 - archetypal - INFO - No 'ZONEVENTILATION:WINDANDSTACKOPENAREA' created since IsNatVentOn == False.
# INFO - 2023-04-21 18:40:47,914 - archetypal - INFO - No 'ZONEVENTILATION:DESIGNFLOWRATE' created since IsScheduledVentilationOn == False.
# INFO - 2023-04-21 18:40:47,914 - archetypal - INFO - No 'ZONEVENTILATION:WINDANDSTACKOPENAREA' created since IsNatVentOn == False.
# INFO - 2023-04-21 18:40:48,085 - archetypal - INFO - No 'ZONEVENTILATION:DESIGNFLOWRATE' created since IsScheduledVentilationOn == False.
# INFO - 2023-04-21 18:40:48,085 - archetypal - INFO - No 'ZONEVENTILATION:WINDANDSTACKOPENAREA' created since IsNatVentOn == False.
# INFO - 2023-04-21 18:40:48,256 - archetypal - INFO - No 'ZONEVENTILATION:DESIGNFLOWRATE' created since IsScheduledVentilationOn == False.
# INFO - 2023-04-21 18:40:48,256 - archetypal - INFO - No 'ZONEVENTILATION:WINDANDSTACKOPENAREA' created since IsNatVentOn == False.
# INFO - 2023-04-21 18:40:48,426 - archetypal - INFO - No 'ZONEVENTILATION:DESIGNFLOWRATE' created since IsScheduledVentilationOn == False.
# INFO - 2023-04-21 18:40:48,426 - archetypal - INFO - No 'ZONEVENTILATION:WINDANDSTACKOPENAREA' created since IsNatVentOn == False.
# INFO - 2023-04-21 18:40:48,597 - archetypal - INFO - No 'ZONEVENTILATION:DESIGNFLOWRATE' created since IsScheduledVentilationOn == False.
# INFO - 2023-04-21 18:40:48,597 - archetypal - INFO - No 'ZONEVENTILATION:WINDANDSTACKOPENAREA' created since IsNatVentOn == False.
# INFO - 2023-04-21 18:40:48,769 - archetypal - INFO - No 'ZONEVENTILATION:DESIGNFLOWRATE' created since IsScheduledVentilationOn == False.
# INFO - 2023-04-21 18:40:48,769 - archetypal - INFO - No 'ZONEVENTILATION:WINDANDSTACKOPENAREA' created since IsNatVentOn == False.
# INFO - 2023-04-21 18:40:48,942 - archetypal - INFO - No 'ZONEVENTILATION:DESIGNFLOWRATE' created since IsScheduledVentilationOn == False.
# INFO - 2023-04-21 18:40:48,942 - archetypal - INFO - No 'ZONEVENTILATION:WINDANDSTACKOPENAREA' created since IsNatVentOn == False.
# downloading parametric/6df56aa8-131f-494d-a9f5-67b9aa5474a1/parameters.json: 100%|██████████| 16.5k/16.5k [00:00<00:00, 224kB/s]
# INFO - ExpandObjects Started.
# INFO - 2023-04-21 18:40:49,482 - in_0.idf - INFO - ExpandObjects Started.
# INFO -  Begin reading Energy+.idd file.
# INFO - 2023-04-21 18:40:49,541 - in_0.idf - INFO -  Begin reading Energy+.idd file.
# INFO -  Done reading Energy+.idd file.
# INFO - 2023-04-21 18:40:49,587 - in_0.idf - INFO -  Done reading Energy+.idd file.
# INFO - ExpandObjects Finished. Time:     0.110
# INFO - 2023-04-21 18:40:49,590 - in_0.idf - INFO - ExpandObjects Finished. Time:     0.110
# INFO - ExpandObjects completed in 0.11 seconds
# INFO - 2023-04-21 18:40:49,591 - in_0.idf - INFO - ExpandObjects completed in 0.11 seconds
# INFO - 2023-04-21 18:40:49,605 - aws_batch.idf_measures.rotate - INFO - 'ROTATE' is not a variable.
# INFO - 2023-04-21 18:40:49,606 - aws_batch.idf_measures.windows_measures - INFO - 'None' is not a variable.
# INFO - 2023-04-21 18:40:49,607 - aws_batch.idf_measures.windows_measures - INFO - 'WINU' or 'WINSHGC' is not a variable.
# INFO - 2023-04-21 18:40:49,607 - aws_batch.idf_measures.windows_measures - INFO - 'None' is not a variable.
# INFO - 2023-04-21 18:40:49,608 - aws_batch.idf_measures.windows_measures - INFO - 'WINUN' or 'WINSHGCN' is not a variable.
# INFO - 2023-04-21 18:40:49,608 - aws_batch.idf_measures.windows_measures - INFO - 'None' is not a variable.
# INFO - 2023-04-21 18:40:49,609 - aws_batch.idf_measures.windows_measures - INFO - 'WINUE' or 'WINSHGCE' is not a variable.
# INFO - 2023-04-21 18:40:49,609 - aws_batch.idf_measures.windows_measures - INFO - 'None' is not a variable.
# INFO - 2023-04-21 18:40:49,609 - aws_batch.idf_measures.windows_measures - INFO - 'WINUS' or 'WINSHGCS' is not a variable.
# INFO - 2023-04-21 18:40:49,609 - aws_batch.idf_measures.windows_measures - INFO - 'None' is not a variable.
# INFO - 2023-04-21 18:40:49,610 - aws_batch.idf_measures.windows_measures - INFO - 'WINUW' or 'WINSHGCW' is not a variable.
# INFO - 2023-04-21 18:40:50,372 - aws_batch.idf_measures.windows_measures - INFO - Final window constructions are:
# INFO -                           0
# INFO - Azimuth
# INFO - 180      Boston_Dbl_Air_Cl
# INFO - 90       Boston_Dbl_Air_Cl
# INFO - 0        Boston_Dbl_Air_Cl
# INFO - 270      Boston_Dbl_Air_Cl
# INFO - 2023-04-21 18:40:50,372 - aws_batch.idf_measures.shading - INFO - 'SHADING_OVERHANG_PROJECTION' is not a variable.
# INFO - 2023-04-21 18:40:50,372 - aws_batch.idf_measures.change_formfactor - INFO - 'FORMFACT' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.rescale - INFO - 'SCALE_X' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.wall_measures - INFO - 'WALLR' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.roof_measures - INFO - 'ROOFR' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.infiltration - INFO - 'INFIL' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.zone_loads - INFO - 'EPDSCH' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.zone_loads - INFO - 'LPDSCH' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.zone_loads - INFO - 'EPD' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.zone_loads - INFO - 'LPD' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.zone_loads - INFO - 'OCCSCH' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.zone_loads - INFO - 'HTGSPSCH' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.zone_loads - INFO - 'CLGSPSCH' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.energy_recovery - INFO - 'HRV' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.mech_ventilation - INFO - 'ACH' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.mech_ventilation - INFO - 'VENTSCH' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.humidity_control - INFO - 'HUMIDMAX' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.supply_air_temperature - INFO - 'SATRESET' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.fan_power - INFO - 'FANPOWER' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.fan_power - INFO - 'FANPOWERMINIMUMFLOWFRACTION' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.fan_power - INFO - 'DELTA_FANPOWER' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.set_outdoor_air - INFO - 'DELTA_FANPOWER' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.set_economizer - INFO - 'ECON' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.electrification - INFO - 'ELECTRIFICATION' is not a variable.
# INFO - 2023-04-21 18:40:50,373 - aws_batch.idf_measures.thermal_mass - INFO - 'THERMALMASS' is not a variable.
# INFO - 2023-04-21 18:40:50,374 - aws_batch.idf_measures.natural_ventilation - INFO - 'NATVENT_ACH' is not a variable.
# INFO - 2023-04-21 18:40:50,374 - aws_batch.idf_measures.zone_loads - INFO - 'USESCH' is not a variable.
# INFO - 2023-04-21 18:40:50,761 - aws_batch.energyplus.energyPlusProcess - INFO - Uploaded IDF file to 's3://surrogate-api/parametric/6df56aa8-131f-494d-a9f5-67b9aa5474a1/idfs/in_0.idf'
# /usr/local/EnergyPlus-22-1-0/ExpandObjects #0-in_0.idf: 4.00it [00:00, 26.2it/s]
# INFO - ExpandObjects Started.
# INFO - 2023-04-21 18:40:50,960 - in_0.idf - INFO - ExpandObjects Started.
# INFO - No expanded file generated.
# INFO - 2023-04-21 18:40:51,054 - in_0.idf - INFO - No expanded file generated.
# INFO - ExpandObjects Finished. Time:     0.071
# INFO - 2023-04-21 18:40:51,054 - in_0.idf - INFO - ExpandObjects Finished. Time:     0.071
# INFO - ExpandObjects completed in 0.10 seconds
# INFO - 2023-04-21 18:40:51,054 - in_0.idf - INFO - ExpandObjects completed in 0.10 seconds
# /usr/local/EnergyPlus-22-1-0/ExpandObjects #0-in_0.idf: 3.00it [00:00, 27.4it/s]
# INFO - Simulation started
# INFO - 2023-04-21 18:40:51,575 - in_0.idf - INFO - Simulation started
# INFO - EnergyPlus Starting
# INFO - 2023-04-21 18:40:51,763 - in_0.idf - INFO - EnergyPlus Starting
# INFO - EnergyPlus, Version 22.1.0-ed759b17ee, YMD=2023.04.21 18:40
# INFO - 2023-04-21 18:40:51,763 - in_0.idf - INFO - EnergyPlus, Version 22.1.0-ed759b17ee, YMD=2023.04.21 18:40
# INFO - Initializing Response Factors
# INFO - 2023-04-21 18:40:52,044 - in_0.idf - INFO - Initializing Response Factors
# INFO - Calculating CTFs for "BOSTON_OFF_FAC_0"
# INFO - 2023-04-21 18:40:52,045 - in_0.idf - INFO - Calculating CTFs for "BOSTON_OFF_FAC_0"
# INFO - Calculating CTFs for "BOSTON_OFF_GRO_0"

# %%
results = analysis.get_results()
results.to_df()
# Out:
#     WINSHGC  SHADING_OVERHANG_PROJECTION  WINU  EUI_kBtu_per_sqft  \
# 0     0.000                     0.000000  0.45          77.078455
# 1     0.000                     1.000000  0.45          65.456402
# 2     0.045                     0.590909  0.45          62.054719
# 3     0.066                     0.000000  0.45          61.567731
# 4     0.132                     0.000000  0.45          61.049308
# 5     0.135                     0.500000  0.45          60.474044
# 6     0.198                     0.000000  0.45          61.451002
# 7     0.225                     0.954545  0.45          59.839208
# 8     0.264                     0.000000  0.45          62.125604
# 9     0.315                     0.045455  0.45          62.643136
# 10    0.330                     0.000000  0.45          63.178785
# 11    0.396                     0.000000  0.45          64.513675
# 12    0.405                     0.227273  0.45          62.938206
# 13    0.462                     0.000000  0.45          66.096969
# 14    0.495                     0.863636  0.45          60.677989
# 15    0.528                     0.000000  0.45          67.718108
# 16    0.585                     0.409091  0.45          64.604545
# 17    0.594                     0.000000  0.45          69.628704
# 18    0.660                     0.000000  0.45          71.642268
# 19    0.675                     0.772727  0.45          63.168504
# 20    0.726                     0.000000  0.45          73.757005
# 21    0.765                     0.318182  0.45          69.543125
# 22    0.792                     0.000000  0.45          75.879255
# 23    0.855                     0.681818  0.45          66.864367
# 24    0.858                     0.000000  0.45          78.077019
# 25    0.924                     0.000000  0.45          80.457993
# 26    0.945                     0.136364  0.45          77.684083
# 27    0.990                     0.000000  0.45          81.976404
# 28    0.990                     0.066667  0.45          80.261862
# 29    0.990                     0.133333  0.45          78.586958
# 30    0.990                     0.200000  0.45          77.105168
# 31    0.990                     0.266667  0.45          75.744292
# 32    0.990                     0.333333  0.45          74.421902
# 33    0.990                     0.400000  0.45          73.146449
# 34    0.990                     0.466667  0.45          71.939817
# 35    0.990                     0.533333  0.45          70.970430
# 36    0.990                     0.600000  0.45          69.976089
# 37    0.990                     0.666667  0.45          69.084173
# 38    0.990                     0.733333  0.45          68.251204
# 39    0.990                     0.800000  0.45          67.511362
# 40    0.990                     0.866667  0.45          66.787626
# 41    0.990                     0.933333  0.45          66.101238
# 42    0.990                     1.000000  0.45          65.477463
#
#     TEDI_kBtu_per_sqft  CEDI_kBtu_per_sqft  EDI_kBtu_per_sqft  \
# 0            17.087779           29.828788          46.916567
# 1            18.417865           20.588968          39.006833
# 2            22.765415           15.041789          37.807204
# 3            22.177785           15.025366          37.203151
# 4            20.431651           15.846606          36.278257
# 5            20.829546           15.185855          36.015401
# 6            19.134375           17.050540          36.184915
# 7            20.013631           15.276359          35.289990
# 8            18.032004           18.314744          36.346748
# 9            17.391018           19.152022          36.543040
# 10           17.103495           19.728143          36.831638
# 11           16.343632           21.227542          37.571174
# 12           16.740732           19.877737          36.618469
# 13           15.749332           22.790167          38.539499
# 14           17.193475           17.948817          35.142292
# 15           15.223862           24.317817          39.541679
# 16           15.684910           21.901365          37.586275
# 17           14.879320           25.959090          40.838410
# 18           14.643903           27.594831          42.238734
# 19           15.808264           20.798125          36.606389
# 20           14.519418           29.234584          43.754002
# 21           14.758078           26.168458          40.926536
# 22           14.471911           30.818328          45.290239
# 23           14.940792           24.175488          39.116280
# 24           14.496338           32.416820          46.913158
# 25           14.625601           34.103277          48.728878
# 26           14.518049           32.198086          46.716135
# 27           14.583639           35.244485          49.828124
# 28           14.508704           34.068584          48.577288
# 29           14.467220           32.889739          47.356959
# 30           14.451880           31.856463          46.308343
# 31           14.465040           30.926686          45.391726
# 32           14.479722           29.992396          44.472118
# 33           14.464235           29.095562          43.559797
# 34           14.442198           28.242847          42.685045
# 35           14.490145           27.537299          42.027444
# 36           14.527698           26.783533          41.311231
# 37           14.568372           26.100684          40.669056
# 38           14.617378           25.446079          40.063457
# 39           14.660904           24.874639          39.535543
# 40           14.704211           24.307771          39.011982
# 41           14.761974           23.749590          38.511564
# 42           14.826786           23.230965          38.057751
#
#     sensible_peak_cooling_W_per_sqft  sensible_peak_heating_W_per_sqft  \
# 0                           5.607416                          2.896522
# 1                           3.973989                          3.488250
# 2                           2.740831                          4.177705
# 3                           2.776683                          4.033860
# 4                           2.988633                          3.811672
# 5                           2.798027                          4.230786
# 6                           3.285465                          3.578389
# 7                           2.916518                          4.052917
# 8                           3.566736                          3.631162
# 9                           3.713927                          3.946808
# 10                          3.827524                          3.357415
# 11                          4.084738                          3.245655
# 12                          3.779457                          3.240723
# 13                          4.356538                          2.631495
# 14                          3.446251                          3.330589
# 15                          4.631956                          2.666613
# 16                          4.035361                          2.616569
# 17                          4.904498                          2.569224
# 18                          5.166984                          2.547250
# 19                          3.828000                          2.869609
# 20                          5.434589                          2.536799
# 21                          4.715373                          2.503213
# 22                          5.704179                          2.469600
# 23                          4.280984                          2.504294
# 24                          5.970808                          2.417465
# 25                          6.234570                          2.383912
# 26                          5.824308                          2.387480
# 27                          6.442328                          2.245627
# 28                          6.191366                          2.336420
# 29                          5.946037                          2.377537
# 30                          5.708318                          2.369266
# 31                          5.488539                          2.412744
# 32                          5.294149                          2.457541
# 33                          5.119684                          2.426560
# 34                          4.960561                          2.490050
# 35                          4.804626                          2.455987
# 36                          4.673597                          2.450599
# 37                          4.556930                          2.490115
# 38                          4.451972                          2.465522
# 39                          4.354206                          2.488971
# 40                          4.307468                          2.532502
# 41                          4.287314                          2.525659
# 42                          4.271102                          2.587717
#
#    time_of_peak_cooling time_of_peak_heating  peak_heating_W_per_sqft  \
# 0          11-JUL-16:00         23-JAN-05:40                 4.520780
# 1          11-JUL-13:40         23-JAN-05:52                 4.905911
# 2          25-JUL-12:05         23-JAN-02:02                 4.758256
# 3          01-AUG-12:05         23-JAN-05:37                 4.761738
# 4          11-JUL-16:00         23-JAN-02:50                 4.675877
# 5          11-JUL-16:00         23-JAN-05:54                 4.707082
# 6          11-JUL-16:00         23-JAN-02:51                 4.902843
# 7          11-JUL-16:00         23-JAN-02:08                 4.659259
# 8          11-JUL-16:00         23-JAN-03:33                 4.801022
# 9          11-JUL-16:00         23-JAN-05:52                 4.791854
# 10         11-JUL-16:00         23-JAN-05:40                 4.747838
# 11         11-JUL-16:00         23-JAN-05:34                 4.466914
# 12         11-JUL-16:00         23-JAN-01:43                 4.739096
# 13         11-JUL-16:00         23-JAN-01:00                 4.395918
# 14         11-JUL-13:40         23-JAN-02:07                 4.521654
# 15         11-JUL-16:00         23-JAN-04:00                 4.385170
# 16         11-JUL-16:00         23-JAN-05:55                 4.370605
# 17         11-JUL-16:00         23-JAN-05:10                 4.283386
# 18         11-JUL-16:00         23-JAN-02:30                 4.177511
# 19         11-JUL-16:00         23-JAN-05:21                 4.523239
# 20         11-JUL-16:00         23-JAN-05:50                 4.281027
# 21         11-JUL-16:00         23-JAN-05:15                 4.222948
# 22         11-JUL-16:00         23-JAN-06:10                 4.214882
# 23         11-JUL-16:00         23-JAN-04:05                 4.258731
# 24         11-JUL-16:00         23-JAN-04:00                 4.151648
# 25         11-JUL-16:00         23-JAN-05:40                 3.978686
# 26         11-JUL-16:00         23-JAN-05:25                 3.936967
# 27         11-JUL-16:00         23-JAN-06:00                 3.838271
# 28         11-JUL-16:00         23-JAN-06:15                 3.861021
# 29         11-JUL-16:00         23-JAN-05:35                 3.959305
# 30         11-JUL-16:00         23-JAN-05:00                 4.091530
# 31         11-JUL-16:00         23-JAN-06:10                 4.155198
# 32         11-JUL-16:00         23-JAN-06:00                 4.195692
# 33         11-JUL-16:00         23-JAN-06:50                 4.137097
# 34         11-JUL-16:00         23-JAN-06:00                 4.249380
# 35         11-JUL-16:00         23-JAN-04:00                 4.253239
# 36         11-JUL-16:00         23-JAN-05:20                 4.132656
# 37         11-JUL-16:00         23-JAN-04:30                 4.298900
# 38         11-JUL-16:00         23-JAN-02:70                 4.292831
# 39         11-JUL-16:00         23-JAN-05:15                 4.199570
# 40         11-JUL-13:40         23-JAN-07:00                 4.361965
# 41         11-JUL-13:40         23-JAN-05:35                 4.263629
# 42         11-JUL-13:40         23-JAN-04:00                 4.320378
#
#     peak_cooling_W_per_sqft
# 0                  8.248869
# 1                  6.247556
# 2                  5.119144
# 3                  5.170281
# 4                  5.150287
# 5                  5.267505
# 6                  5.303288
# 7                  5.263242
# 8                  5.409111
# 9                  5.903712
# 10                 5.668263
# 11                 6.236958
# 12                 6.179929
# 13                 6.650844
# 14                 5.296549
# 15                 7.276620
# 16                 6.762206
# 17                 6.979436
# 18                 7.182946
# 19                 5.777284
# 20                 8.114119
# 21                 7.105878
# 22                 7.596542
# 23                 6.314713
# 24                 7.895318
# 25                 8.177508
# 26                 7.806402
# 27                 8.438653
# 28                 8.112062
# 29                 8.765487
# 30                 8.700090
# 31                 8.493522
# 32                 7.065435
# 33                 8.164700
# 34                 6.745057
# 35                 6.595913
# 36                 6.456617
# 37                 7.014234
# 38                 7.135958
# 39                 6.972324
# 40                 6.983722
# 41                 6.803308
# 42                 6.370241
